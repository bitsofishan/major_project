# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"data.csv")
data
# Out:
#       cx_square  cy_square  cx_hexa  cy_hexa  cx_sept  cy_sept  cx_pent  \
# 0           389        502      391      393      388      592      230
# 1           518        528      506      431      530      611      376
# 2           547        525      535      428      559      608      404
# 3           554        514      542      416      566      597      411
# 4           555        498      543      399      565      580      411
# ...         ...        ...      ...      ...      ...      ...      ...
# 1026        315        362      312      434      312      302      416
# 1027        282        391      278      462      279      331      383
# 1028        249        432      245      502      247      373      351
# 1029        225        470      219      540      224      411      326
# 1030        225        502      217      573      225      444      326
#
#       cy_pent  cx_triangle  cy_triangle          X         Y          Z
# 0         501          533          502  47.630973  1.959253  -5.144614
# 1         534          651          521  47.166674  1.713366  -7.558380
# 2         532          682          519  47.335970  0.654571  -9.487253
# 3         520          690          507  47.301259 -1.078294 -11.537369
# 4         504          690          491  47.262419 -3.110282 -14.191243
# ...       ...          ...          ...        ...       ...        ...
# 1026      364          214          361  41.974050  2.008992  -7.466595
# 1027      393          180          390  41.787616  3.521731  -7.656033
# 1028      433          146          431  42.092724  3.910180  -7.608388
# 1029      471          122          469  42.631452  3.889939  -7.791588
# 1030      503          122          502  43.028682  3.165146  -7.637914
#
# [1031 rows x 13 columns]

# %%
sns.pairplot(data);

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.gca()
data.hist(ax = ax)
# Out:
# <ipython-input-7-ba355f8f7bbe>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   data.hist(ax = ax)
# array([[<AxesSubplot:title={'center':'cx_square'}>,
#         <AxesSubplot:title={'center':'cy_square'}>,
#         <AxesSubplot:title={'center':'cx_hexa'}>,
#         <AxesSubplot:title={'center':'cy_hexa'}>],
#        [<AxesSubplot:title={'center':'cx_sept'}>,
#         <AxesSubplot:title={'center':'cy_sept'}>,
#         <AxesSubplot:title={'center':'cx_pent'}>,
#         <AxesSubplot:title={'center':'cy_pent'}>],
#        [<AxesSubplot:title={'center':'cx_triangle'}>,
#         <AxesSubplot:title={'center':'cy_triangle'}>,
#         <AxesSubplot:title={'center':'X'}>,
#         <AxesSubplot:title={'center':'Y'}>],
#        [<AxesSubplot:title={'center':'Z'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
